# %% [markdown]
# # 02 — Machine Learning Classification Pipeline
#
# Trains and evaluates ~12 classifiers on the PIMA dataset with 5-fold cross-validation, confusion matrices, ROC curves, and feature importance.
#
# Extends Mujumdar & Vaidehi (2019)'s classifier comparison with proper CV (not single-split accuracy), more models, and interpretability plots.

# %%
import sys
sys.path.append('../src')
from ml_pipeline import run_ml_pipeline

# %% [markdown]
# ## Run the full ML pipeline
# This will:
# 1. Preprocess the data
# 2. Run 5-fold CV on every model
# 3. Fit on the full training set, evaluate on held-out test set
# 4. Save confusion matrices, ROC curves, accuracy comparison, and feature importance plots
# 5. Save the best model's metrics to `results/tables/ml_handoff_metrics.json` (used by the population ODE model's ML-informed scenario)

# %%
results_df, cv_results, handoff = run_ml_pipeline()
# Out:
# [preprocessing] Loaded REAL dataset from /Users/arpitjha/projects/DBPS/notebooks/../src/../data/raw/pima.csv (768 rows).
# [preprocessing] Missing values imputed (median) per column:
# Glucose            5
# BloodPressure     35
# SkinThickness    227
# Insulin          374
# BMI               11
# [preprocessing] EDA figures saved to /Users/arpitjha/projects/DBPS/results/figures
# [preprocessing] Cleaned data saved to /Users/arpitjha/projects/DBPS/data/processed/pima_clean.csv
#
# [ml_pipeline] === Cross-validation (5-fold) ===
# [ml_pipeline] CV done: Logistic Regression    acc=0.787±0.019
# [ml_pipeline] CV done: KNN                    acc=0.752±0.035
# [ml_pipeline] CV done: Naive Bayes            acc=0.762±0.028
# [ml_pipeline] CV done: Decision Tree          acc=0.664±0.008
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:200: RuntimeWarning: divide by zero encountered in matmul
#   raw_prediction = X @ weights + intercept
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:200: RuntimeWarning: overflow encountered in matmul
#   raw_prediction = X @ weights + intercept
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:200: RuntimeWarning: invalid value encountered in matmul
#   raw_prediction = X @ weights + intercept
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:330: RuntimeWarning: divide by zero encountered in matmul
#   grad[:n_features] = X.T @ grad_pointwise + l2_reg_strength * weights
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:330: RuntimeWarning: overflow encountered in matmul
#   grad[:n_features] = X.T @ grad_pointwise + l2_reg_strength * weights
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:330: RuntimeWarning: invalid value encountered in matmul
#   grad[:n_features] = X.T @ grad_pointwise + l2_reg_strength * weights
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:200: RuntimeWarning: divide by zero encountered in matmul
#   raw_prediction = X @ weights + intercept
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:200: RuntimeWarning: overflow encountered in matmul
#   raw_prediction = X @ weights + intercept
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:200: RuntimeWarning: invalid value encountered in matmul
#   raw_prediction = X @ weights + intercept
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:330: RuntimeWarning: divide by zero encountered in matmul
#   grad[:n_features] = X.T @ grad_pointwise + l2_reg_strength * weights
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:330: RuntimeWarning: overflow encountered in matmul
#   grad[:n_features] = X.T @ grad_pointwise + l2_reg_strength * weights
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:330: RuntimeWarning: invalid value encountered in matmul
#   grad[:n_features] = X.T @ grad_pointwise + l2_reg_strength * weights
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:200: RuntimeWarning: divide by zero encountered in matmul
#   raw_prediction = X @ weights + intercept
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:200: RuntimeWarning: overflow encountered in matmul
#   raw_prediction = X @ weights + intercept
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:200: RuntimeWarning: invalid value encountered in matmul
#   raw_prediction = X @ weights + intercept
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:330: RuntimeWarning: divide by zero encountered in matmul
#   grad[:n_features] = X.T @ grad_pointwise + l2_reg_strength * weights
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:330: RuntimeWarning: overflow encountered in matmul
#   grad[:n_features] = X.T @ grad_pointwise + l2_reg_strength * weights
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:330: RuntimeWarning: invalid value encountered in matmul
#   grad[:n_features] = X.T @ grad_pointwise + l2_reg_strength * weights
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:200: RuntimeWarning: divide by zero encountered in matmul
#   raw_prediction = X @ weights + intercept
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:200: RuntimeWarning: overflow encountered in matmul
#   raw_prediction = X @ weights + intercept
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:200: RuntimeWarning: invalid value encountered in matmul
#   raw_prediction = X @ weights + intercept
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:330: RuntimeWarning: divide by zero encountered in matmul
#   grad[:n_features] = X.T @ grad_pointwise + l2_reg_strength * weights
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:330: RuntimeWarning: overflow encountered in matmul
#   grad[:n_features] = X.T @ grad_pointwise + l2_reg_strength * weights
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:330: RuntimeWarning: invalid value encountered in matmul
#   grad[:n_features] = X.T @ grad_pointwise + l2_reg_strength * weights
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:200: RuntimeWarning: divide by zero encountered in matmul
#   raw_prediction = X @ weights + intercept
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:200: RuntimeWarning: overflow encountered in matmul
#   raw_prediction = X @ weights + intercept
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:200: RuntimeWarning: invalid value encountered in matmul
#   raw_prediction = X @ weights + intercept
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:330: RuntimeWarning: divide by zero encountered in matmul
#   grad[:n_features] = X.T @ grad_pointwise + l2_reg_strength * weights
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:330: RuntimeWarning: overflow encountered in matmul
#   grad[:n_features] = X.T @ grad_pointwise + l2_reg_strength * weights
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:330: RuntimeWarning: invalid value encountered in matmul
#   grad[:n_features] = X.T @ grad_pointwise + l2_reg_strength * weights
# [ml_pipeline] CV done: Random Forest          acc=0.769±0.015
# [ml_pipeline] CV done: Extra Trees            acc=0.764±0.007
# [ml_pipeline] CV done: SVM (RBF)              acc=0.779±0.008
# [ml_pipeline] CV done: LDA                    acc=0.787±0.022
# [ml_pipeline] CV done: AdaBoost               acc=0.770±0.014
# [ml_pipeline] CV done: Gradient Boosting      acc=0.749±0.020
# [ml_pipeline] CV done: Bagging                acc=0.764±0.033
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:200: RuntimeWarning: divide by zero encountered in matmul
#   raw_prediction = X @ weights + intercept
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:200: RuntimeWarning: overflow encountered in matmul
#   raw_prediction = X @ weights + intercept
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:200: RuntimeWarning: invalid value encountered in matmul
#   raw_prediction = X @ weights + intercept
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:330: RuntimeWarning: divide by zero encountered in matmul
#   grad[:n_features] = X.T @ grad_pointwise + l2_reg_strength * weights
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:330: RuntimeWarning: overflow encountered in matmul
#   grad[:n_features] = X.T @ grad_pointwise + l2_reg_strength * weights
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:330: RuntimeWarning: invalid value encountered in matmul
#   grad[:n_features] = X.T @ grad_pointwise + l2_reg_strength * weights
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# [ml_pipeline] CV done: MLP (ANN)              acc=0.726±0.027
#
# [ml_pipeline] === Holdout evaluation ===
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:200: RuntimeWarning: divide by zero encountered in matmul
#   raw_prediction = X @ weights + intercept
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:200: RuntimeWarning: overflow encountered in matmul
#   raw_prediction = X @ weights + intercept
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:200: RuntimeWarning: invalid value encountered in matmul
#   raw_prediction = X @ weights + intercept
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:330: RuntimeWarning: divide by zero encountered in matmul
#   grad[:n_features] = X.T @ grad_pointwise + l2_reg_strength * weights
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:330: RuntimeWarning: overflow encountered in matmul
#   grad[:n_features] = X.T @ grad_pointwise + l2_reg_strength * weights
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:330: RuntimeWarning: invalid value encountered in matmul
#   grad[:n_features] = X.T @ grad_pointwise + l2_reg_strength * weights
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/arpitjha/projects/DBPS/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# [ml_pipeline] Selecting best model by F1: AdaBoost
# [ml_pipeline] Saved best model by F1 (AdaBoost, F1=0.634) -> /Users/arpitjha/projects/DBPS/notebooks/../src/../models/best_model_adaboost.pkl
# [ml_pipeline] Saved AdaBoost (Acc=0.760, F1=0.634) -> /Users/arpitjha/projects/DBPS/notebooks/../src/../models/adaboost_model.pkl
# [ml_pipeline] AdaBoost is the best model here too -- consistent with Mujumdar & Vaidehi (2019)'s finding. Good literature-agreement point for the report.
#
# [ml_pipeline] Best model: AdaBoost
# [ml_pipeline] Results table:
#                Model  Accuracy  Precision  Recall    F1   AUC
#            AdaBoost     0.760      0.681   0.593 0.634 0.818
#   Gradient Boosting     0.760      0.689   0.574 0.626 0.831
#                 KNN     0.740      0.635   0.611 0.623 0.795
#           SVM (RBF)     0.740      0.652   0.556 0.600 0.796
#         Naive Bayes     0.701      0.567   0.630 0.596 0.765
#         Extra Trees     0.721      0.608   0.574 0.590 0.805
#       Random Forest     0.734      0.644   0.537 0.586 0.818
#             Bagging     0.727      0.636   0.519 0.571 0.812
#           MLP (ANN)     0.695      0.569   0.537 0.552 0.777
# Logistic Regression     0.708      0.600   0.500 0.545 0.813
#                 LDA     0.701      0.591   0.481 0.531 0.813
#       Decision Tree     0.682      0.553   0.481 0.515 0.636
#
# [ml_pipeline] All figures saved to /Users/arpitjha/projects/DBPS/results/figures
# [ml_pipeline] All tables saved to /Users/arpitjha/projects/DBPS/results/tables
# [ml_pipeline] Handoff metrics for ODE module saved to ml_handoff_metrics.json

# %% [markdown]
# ## Cross-validation results (mean ± std, not single-point estimates)

# %%
cv_results[['Model', 'accuracy_mean', 'accuracy_std', 'recall_mean', 'recall_std', 'f1_mean', 'f1_std']]
# Out:
#                   Model  accuracy_mean  accuracy_std  recall_mean  recall_std  \
# 0   Logistic Regression       0.786605      0.019300     0.570100    0.018026
# 1                   LDA       0.786605      0.022465     0.574751    0.022728
# 2             SVM (RBF)       0.778502      0.007925     0.574862    0.067369
# 3              AdaBoost       0.770359      0.013964     0.598117    0.027059
# 4         Random Forest       0.768733      0.015017     0.593466    0.023273
# 5           Extra Trees       0.763854      0.006882     0.579623    0.042364
# 6               Bagging       0.763841      0.033332     0.602547    0.041566
# 7           Naive Bayes       0.762268      0.027954     0.598450    0.051747
# 8                   KNN       0.752419      0.035269     0.565338    0.024886
# 9     Gradient Boosting       0.749154      0.019931     0.579291    0.040372
# 10            MLP (ANN)       0.726403      0.027309     0.593466    0.056014
# 11        Decision Tree       0.664494      0.007929     0.565559    0.048822
#
#      f1_mean    f1_std
# 0   0.651082  0.023675
# 1   0.652909  0.031454
# 2   0.642189  0.024379
# 3   0.644846  0.015369
# 4   0.641672  0.008529
# 5   0.630435  0.016340
# 6   0.640881  0.039231
# 7   0.636877  0.038406
# 8   0.615750  0.035930
# 9   0.616747  0.023888
# 10  0.601170  0.044054
# 11  0.539274  0.021413

# %% [markdown]
# ## Held-out test set results

# %%
results_df
# Out:
#                   Model  Accuracy  Precision    Recall        F1       AUC
# 0              AdaBoost  0.759740   0.680851  0.592593  0.633663  0.817870
# 1     Gradient Boosting  0.759740   0.688889  0.574074  0.626263  0.830741
# 2                   KNN  0.740260   0.634615  0.611111  0.622642  0.795093
# 3             SVM (RBF)  0.740260   0.652174  0.555556  0.600000  0.796389
# 4           Naive Bayes  0.701299   0.566667  0.629630  0.596491  0.764630
# 5           Extra Trees  0.720779   0.607843  0.574074  0.590476  0.805000
# 6         Random Forest  0.733766   0.644444  0.537037  0.585859  0.817500
# 7               Bagging  0.727273   0.636364  0.518519  0.571429  0.812315
# 8             MLP (ANN)  0.694805   0.568627  0.537037  0.552381  0.777037
# 9   Logistic Regression  0.707792   0.600000  0.500000  0.545455  0.812963
# 10                  LDA  0.701299   0.590909  0.481481  0.530612  0.812593
# 11        Decision Tree  0.681818   0.553191  0.481481  0.514851  0.635741

# %% [markdown]
# ## Handoff metrics passed to the population ODE model

# %%
handoff
# Out:
# {'best_model': 'AdaBoost',
#  'accuracy': 0.7597402597402597,
#  'recall_sensitivity': 0.5925925925925926,
#  'precision': 0.6808510638297872,
#  'f1': 0.6336633663366337,
#  'auc': 0.8178703703703704}

# %% [markdown]
# Figures generated (see `results/figures/`):
# - `05_confusion_matrices.png`
# - `06_roc_curves.png`
# - `07_accuracy_comparison.png`
# - `08_feature_importance.png`
#
# Tables generated (see `results/tables/`):
# - `cv_results.csv`
# - `holdout_results.csv`
# - `classification_reports.txt`
# - `ml_handoff_metrics.json`
