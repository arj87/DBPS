# %% [markdown]
# # 01 — Data Preprocessing & Exploratory Data Analysis
#
# Diabetes Prediction Project (DBPS)
#
# This notebook loads the PIMA Indians Diabetes dataset, cleans it (handling biologically-impossible zero values), and produces the EDA figures used in Chapter 4 of the report.
#
# **Before running for real results:** place the real PIMA CSV at `data/raw/pima.csv`. Without it, this notebook falls back to a synthetic placeholder dataset for testing only.

# %%
import sys
sys.path.append('../src')
from preprocessing import preprocess_pipeline

# %% [markdown]
# ## Run the full preprocessing + EDA pipeline

# %%
df_clean = preprocess_pipeline()
df_clean.head()

# %% [markdown]
# ## Summary statistics

# %%
df_clean.describe()

# %% [markdown]
# ## Class balance check

# %%
df_clean['Outcome'].value_counts(normalize=True)

# %% [markdown]
# Figures generated (see `results/figures/`):
# - `01_class_balance.png`
# - `02_correlation_heatmap.png`
# - `03_feature_distributions.png`
# - `04_pairplot.png`
